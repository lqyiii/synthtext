# %%
thresh.mean()
# Out:
# 252.82909962530306

# %%
cv.threshold(gray_img, 200, 255,0)[1].mean()
import os
import numpy as np
file_list=os.listdir('./data/imgs/')
print len(file_list)
# Out:
# 274100

# %%
# 剔除掉不符合要求的图片（1、图片背景颜色太深、找出有一定区分能力的 abs<200；2、剔除宽度特别大的（>75），应该是有问题,长宽比也要考虑;3、字符要都在指定的字典里面）
import cv2 as cv
from matplotlib import pyplot as plt
# %matplotlib inline
img=cv.imread('./data/imgs/eagle_124.jpg_12_1514091603.jpg')

plt.imshow(img), plt.colorbar(),plt.show()
gray_img=cv.cvtColor(img, cv.COLOR_BGR2GRAY)
plt.imshow(gray_img), plt.colorbar(),plt.show()
ret, thresh=cv.threshold(gray_img, 80, 255,0)
plt.imshow(thresh), plt.colorbar(),plt.show()
plt.imshow(cv.threshold(gray_img, 175, 255,0)[1]), plt.colorbar(),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f3760f1efd0>,
# ...
#  None)

# %%
# 剔除掉不符合要求的图片（1、图片背景颜色太深、找出有一定区分能力的 abs<200；2、剔除宽度特别大的（>75），应该是有问题,长宽比也要考虑;3、字符要都在指定的字典里面）
def img_filter(BGR_img,text,dict_words):
    text=text.strip(' ')
    H,W=BGR_img.shape[:2]
    flag=True
    if H>75:
        return False
    if float(H)/W>=1.5:
        return False
    
    count=[dict_words.has_key(i) for i in text].count(False)
    if count>0:
        return False
    return flag

# %%
count=0
while True:
    rand_int=np.random.randint(len(file_list))
    file_name=file_list[rand_int]
    img_=cv.imread('./data/imgs/'+file_name)
    gray_=cv.cvtColor(img_, cv.COLOR_BGR2GRAY)
    
    if img_.shape[0]>70 and float(img_.shape[0])/img_.shape[1]>=1.5:
        count+=1
#         plt.imshow(img_), plt.colorbar(),plt.show()
# #         print cv.threshold(gray_, 60, 255,0)[1].mean()
# #         plt.imshow(cv.threshold(gray_, 60, 255,0)[1]), plt.colorbar(),plt.show()
# #         print cv.threshold(gray_, 175, 255,0)[1].mean()
# #         plt.imshow(cv.threshold(gray_, 175, 255,0)[1]), plt.colorbar(),plt.show()
#         th=cv.adaptiveThreshold(gray_,255,cv.ADAPTIVE_THRESH_MEAN_C,cv.THRESH_BINARY,7,2)
#         print th.mean()
#         plt.imshow(th), plt.colorbar(),plt.show()
#         print '------------------------------'
    if count==10:
        break
# Out:
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-140-a8b482d0d3d7> in <module>()
#      18 #         print '------------------------------'
#      19     else:
# ---> 20         plt.imshow(img_), plt.colorbar(),plt.show()
#      21     if count==10:
#      22         break
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3140            filternorm=1, filterrad=4.0, imlim=None, resample=None, url=None,
#    3141            hold=None, data=None, **kwargs):
# -> 3142     ax = gca()
#    3143     # Deprecated: allow callers to override the hold state
#    3144     # by passing hold=True|False
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in gca(**kwargs)
#     948     matplotlib.figure.Figure.gca : The figure's gca method.
#     949     """
# ...
